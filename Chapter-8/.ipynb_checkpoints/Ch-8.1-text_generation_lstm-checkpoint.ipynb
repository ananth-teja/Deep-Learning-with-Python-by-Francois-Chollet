# %% [markdown]
# ----------
# ### Text Generation with LSTM
#
# -------
#
# Here we will consider the above problem for sequence generation which can be generalized to any sequence generation problem.
#
# -------
#
# ***How to generate sequence data?***
#
# -----
#
# The general way would be to train an RNN to predict the next token or a few tokens uisng previous tokens as an input.
#
# - *Token* is a word or a character, and any model which can predict the next token given the previous one is known as *language-model*. A language model captures the *latent-space* of the language: it's statistical nature.
# - Once we have trained a language model we can sample from it(generate new sequences): you feed it an initial string of text (called conditioning data), and ask it to generate the next token and feed the token again back to the language to model and keep generating text in a loop.
# - This loop allows us to generate the sequences of arbitiary lengths.
# - If we feed N characters to an LSTM, and train it to predict the N+1 character. The output of the model will be a softmax over all possible characters: a probablity distribution for the next character.
# - This is ***Character level neural language model***.
#
# -------
# **Importance of sampling strategy**
#
# -----
#
# When generating text the way we choose the next character is very important.
# - One apporach is simple greedy sampling, consisting of always choosing the next most likely character(one with highest probablity). But this would make the system very predictable.
# - Another interesting approach is to use stochastic sampling i.e. suppose if a probablity of character being the next character is 0.3 then we wil choose the value 30 percent of the time. This would help increase the randomness. This allows even unlikely characters to be sampled some of the time, generating more intersting sentences. But this does not factor in a way to control the randomness of data. We don't want the predictions to be entirely random, i.e. the generated text should be meaningfull. So it is necessary to have a way to control the randomness of the generated text.
# - In order to control the stochasticity of the random process we will introduce a paramater ***stochastic temperature***. that characterizes the entropy of the probablity distribution used for sampling, it characterizes how surprising or predictable the next character will be.
# - This is done by processing the original softmax output by using the temperature value.
#
# The psuedo code for the same looks like -
#
# ```python
# import numpy as np
#
# def reweight_distribution(original_distribution, temperature = 0.5):
#     distribution = np.log(original_distribution) / temperature
#     distribution = np.exp(distribution)
#     return distribution/ np.sum(distribution)
# ```
#
# Higher temperature will result in sampling distributions with higher entropy, and vice versa.
#
# -------
# Let's implement a Character level LSTM text-generation -

# %%
import keras
import numpy as np

path = keras.utils.get_file('nietzsche.txt',
                           origin = 'https://s3.amazonaws.com/text-datasets/nietzsche.txt')
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt

# %%
text = open(path).read().lower()

# %%
len(text)
# Out:
# 600893

# %% [markdown]
# - Next we will extract partially overlapping sequences of length maxlen.
# - One hot encode them.
# - Pack them in a 3D numpy array of shape (sequences, maxlen, unique_characters)
# - Similarly we will also create a numpy array of targets i.e. y and one hot encode them.

# %%
maxlen = 60 
step = 3
sentences = []
next_chars = []

# %%
for i in range(0, len(text)-maxlen, step):
    sentences.append(text[i:i+maxlen])
    next_chars.append(text[i+maxlen])

# %%
len(sentences)
# Out:
# 200278

# %%
### LIST OF UNIQUE CHARACTERS IN THE CHORPUS
chars = sorted(list(set(text)))

# %%
len(chars)
# Out:
# 57

# %%
### Dictionary that maps char to it's index in list "chars".
char_indices = dict((char, chars.index(char)) for char in chars)

# %%
x = np.zeros((len(sentences), maxlen, len(chars)), dtype = np.bool)
y = np.zeros((len(sentences), len(chars)), dtype = np.bool)

# %%
### One hot encoding the Chorpus
for i,sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i,t,char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %% [markdown]
# ***Building the network***

# %%
from keras import layers

# %%
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape = (maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation = 'softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr = 0.01)
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer)

# %% [markdown]
# ***Training the language model and sampling from it***
#
# Given a trained model and seed text snippet, we can generate new text by doing the following repeatedly:
#
# - Draw from the model a probablity distribution for the next character, given the generated text available so far.
# - Reweight the distribution to a certain temperature.
# - Sample the next character at random according to redistributed distribution.
# - Add the character at the end of the available text.

# %% [markdown]
# -------
#
# ***Function to sample the next character given the model's predictions***
#
# ----

# %%
def sample(preds, temperature = 1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds)/ temperature
    exp_preds = np.exp(preds)
    preds = exp_preds/np.sum(exp_preds)
    
    ### Draw samples from a multinomial distribution.
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# ***Text generating loop***

# %%
import random
import sys

for epoch in range(1,60):
    
    print("\n ----------Epoch : " + str(epoch) + "---------- \n")
    model.fit(x, y, batch_size = 128, epochs = 1)
    
    ### Selecting a random seed
    start_index = random.randint(0, len(text)- maxlen-1)
    generated_text = text[start_index:start_index + maxlen]
    
    for temperature in [0.2,0.5,1.0,1.2]:
        print("\n ------------------Temperature :" +  str(temperature) + "---------- \n")
        sys.stdout.write(generated_text)
        
        for i in range(400):
            ### One hot encoded vector for generated text
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0,t,char_indices[char]] = 1.
            preds = model.predict(sampled, verbose = 0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
# Out:
#  ----------Epoch : 1----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 78s - loss: 1.9532
#
#  ------------------Temperature :0.2----------
#
# llow him
# more cordially and thoroughly;--the genius of the has the superfict of the thing has the for the and in the fact of the condidion of the thing of the the thing and cause of the this and the interits of the selogion of the this under the into the consequent of the strugh the interits of the seloct that it is the has in the provient the interits its of the thing of the selors of the superfors of the this of the care and this in the selocs of the thi
#  ------------------Temperature :0.5----------
#
# rs of the this of the care and this in the selocs of the things for and that has in the philosoph that the indualing of all explasion the into the antion of labifion of the may in order to be the invignes of under the nother to be instinct of the the wholice that the propuction of the find the plives and carture is all the can its and the conterness of the explant and and and why all this for the knewn this popsible of the what sperious philosophers of man
#  ------------------Temperature :1.0----------
#
# knewn this popsible of the what sperious philosophers of mantures vaity it rolk intrue of do kand manic of whenwereclitorde of yhance or knowled, whateter of such a prexoss the outtes has in that
# many. the
# wholity adrooks, beliris findm-to the plospent. fariliparation in the topt to should that : readspaty period in ordard and condindion indicquaid
# any exesping of han-.a when has if
# it. here; is he facrus deopted preceation of
# heread my strect. and acouti
#  ------------------Temperature :1.2----------
#
# he facrus deopted preceation of
# heread my strect. and acoution, for tenstacice vordded have eyenonn we bregisted the rame
# thosternes,
# nature of
# mys strengares divinerms, and-"noo, modeschent. spicious thyserom; the hade
# hin;" we hoponishin. in
# leptions--fevony enthically and and plest-and" ah, why may, thisiventomedly dalped expring than that onerquine sa fuccownibl. musit
# evined. for agdealice then ideismednth men--whenoraying of bvenkes  hard. doow-sgs
#  ----------Epoch : 2----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 80s - loss: 1.6139
#
#  ------------------Temperature :0.2----------
#
# s what nature does with matter,[20] promote the purposes and in the contran the sense of the contratively the soul the for the sense of the sense of the contrative and soul the sense of the sense of the soul the sense of the readon to the sense of the soul the sense of the sense of the conscious and soul the soul the conceadence of the sense of the word of the
# charm of the contratively and interponing to the sense of the word of the conceadence of the cont
#  ------------------Temperature :0.5----------
#
# ning to the sense of the word of the conceadence of the contrally science of the allow as a deciging to morality and sensionally and for the
# restort to this for the warting it a morality of the elion of the ancinistant the moral moral dections propostation of the contrations in the
# hast the
# resective of the there in the effect and the explantially believely indifferent for a still belorgor of the contrativing has he can be a there are into the there of gre
#  ------------------Temperature :1.0----------
#
# contrativing has he can be a there are into the there of great chortratific second
# apahys to
# theartistoninonse naturaltest and soup wond of strights and the
# "ghic froung of altxision and the "mast, vidioror, below hall mind evil i socitions achioled which he was upon there
# are this instopidial iffection, that present, and alto they consount
# vieer initamentle sanctibned: one in it one of
# one ledite. alreces of
# word. consected to thinker by the to a such fen
#  ------------------Temperature :1.2----------
#
# . alreces of
# word. consected to thinker by the to a such fenesoxed, much that it wontrey nacultebs, my baibly, fortulgan digriitu--so
# chath : belong so go,
# has, prom and mother belon more into
# one tdocee not the beadtem
# plantshoncy, theytile, wtalire to,
# i
# safurwith, eagu, and ege-com vord,ly ad
# romorthich?
#
#
#        for injulte, one, to you phinosoplh. igeonly shoodstoocevoni"anisad, of one actiamer for that hew "inbef-aincened of doveleted knowlevonrwhang
#  ----------Epoch : 3----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 80s - loss: 1.5293
#
#  ------------------Temperature :0.2----------
#
# oet or
# writer has ever done anything else, and what other purpose of the stranges the stranges of the strength of the subjection of the stranges the strength, and of the belief and man and in the sense of the science, the spirit of the stranges the stranges the sense of the science, the science of the spirit of the stranges and the states and deception of the greates the present the semptation of the states and man has he who standard of the commands of th
#  ------------------Temperature :0.5----------
#
# the states and man has he who standard of the commands of the power and example, as the belief in its among command it is shart that if the belief in the spirits of the ppope of the subfurder the stranges that which where is german the has in its own one is now and my the standard of the problem previled in all shart so there. here and will men as a the spread in the should sentiments and has little it of the should be us the commander that himself.
#
#
# 27
#
#
#  ------------------Temperature :1.0----------
#
# le it of the should be us the commander that himself.
#
#
# 27
#
# =the will wait the values.--when in "case of ill if present--ar affected nothanter, but church theres us
# iousest and wishey of repossible a soul may generation by eirchners here of the necided with long applictive and power
# itheal early character" now
# rtdifies moral the knowledge perforth when occes of end neach surpeerial religious that pined of the fencifel' in which the warch, evereary
# much str
#  ------------------Temperature :1.2----------
#
# pined of the fencifel' in which the warch, evereary
# much strate old
# have uejostling degryek, go free spocioned). and desustness-courvicen, it gerean jest man. of "pire no swhaped f"coners no reperfulness concrepsuable hal for 2her k"quedious the heartly
# hands; accall churche
# her it).
# ? songater
# even bpow mod, it words, spational esurlevas, phyline, every relectues frain
# charrmanting to "which this dreos long h
# u-squalse--by in formed-ger. crum which ourse
#  ----------Epoch : 4----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 79s - loss: 1.4862
#
#  ------------------Temperature :0.2----------
#
# n man lives! one can never cease wondering when once one has he much and such a man and the say, and the world and sense in the sense of the say in the same and the say, and the spirit and supposing the spirit in the spirit and the same that the same that the conscience of the spirit and such a supposing that is the say, and in the spirit of the sense of the saint to the same that the same and at such a soul, and the spirit in the sense of the say for the
#  ------------------Temperature :0.5----------
#
# such a soul, and the spirit in the sense of the say for the spirit in the same that it is it the some stall of the saint in the soul his must a man to expersences superficial the say is are that a moral pleast, which as it is its and the soul and experience has if it is into his man which serie one has all the has into the same and perhaps far the ourselves and world and with a man may be still into the spirit of supposing the means of the seacy what is to
#  ------------------Temperature :1.0----------
#
# to the spirit of supposing the means of the seacy what is to seem heild spirit-freaking any pleasure. which enchmenism flaming, which must ising it opinion of our four earthing, the readly--that certain, equal. as
# pasheded houthergoration to practical hew its own will can be rourder that socou; spirit enthild-is, condust we what is it, seeming", impresssse which he is pits what are returnable bripchs without one starason and founder of where, whe had to re
#  ------------------Temperature :1.2----------
# chs without one starason and founder of where, whe had to really any confrive opion of diaters, yachueted
# truesc heavis, and patter"? hevilover. they wails when he to of litsive with "its, after-count mpdicable sodemness.--evenrthing,, what however mirrlacty pelfor--you howhes undeispialed in vain), exemuc upter.--het should amstroble.--god, ashas for racrs,
# peace owngest  scon
# the dangful man.--of a rild? becipiably worthen
# if oenring toed no, judguly unf
#  ----------Epoch : 5----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 79s - loss: 1.4575
#
#  ------------------Temperature :0.2----------
#
# athens, and wrote three
# hundred books, perhaps out of rage and man and all the man and art and into the sentiments and strong in the self-desires the self-considered to be and and morality of the spirit to be and all the present the sentiments in the seems to be and and into the senses of the strong of the sense of the self-real and all the same the present the self-sentiment and consequently to be and the belief and and all the sentiments and and and and
#  ------------------Temperature :0.5----------
#
# e and the belief and and all the sentiments and and and and new
# with the excession of the more time
# and still have been for in the desirable to be and and morality or dosming and allow once the freally attain expression of the explanation of the attain the same the person all the are of the founderstand and an
# into the self to spome the so all the fatural and endous the all the god; to be things are prom suck for the moral to be disposed and worther to the
#  ------------------Temperature :1.0----------
#
# re prom suck for the moral to be disposed and worther to the lixt2, that a far tan say for, chrision essign from nom--always si whole abecals, they was falled man have been way right of men withdrational vengians of the frighnatenc
# notible to meansar in the proysing if reconditence, all the good sufficient many rewald a would like that ? the can have appear general
# to an everything more the last spicious world on the chrisely which self light acted experie
#  ------------------Temperature :1.2----------
#
# picious world on the chrisely which self light acted experience..). then combarful is disportual rayed! -amely form" fotter of the upon;
#  asfe-mades porter sttro natural constitute.jul. the out regrve--they mart . in bight a
# desires,
# voltage relac
# of effect beforffigdschinmers manjoredouction! nevertange--art shavey his
# prevurally in european, they youghts wors.
#
# 1der
# every gunulty--what , ale(why a libertrachi play, with recogagrhe
# the untalled
# from a hab
#  ----------Epoch : 6----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 79s - loss: 1.4359
#
#  ------------------Temperature :0.2----------
#
# ally only operate on "will"--and not on "matter" (not
# on "necessary in the senses and the morality of the sense and the sense of the same and the and interpretible in the distingues that in the senses and the stronges the suffer and moral and stronger of the senses and the struggle of the senses and the most desires, and in the same the same the most desires and the are the presentionable and partial and the struggle and the presention of the soul, and in
#  ------------------Temperature :0.5----------
#
# ial and the struggle and the presention of the soul, and in the different in suchment, there is time of all the signification to not in the exprated and previous in the same deally and the present the moral highest and nothing and reason to the philosophy have actions, and reason and faith and will the word the same say, in the moral profuse them and presention of the honoural have afford in the same his intertible and modent, the spirit and good believe t
#  ------------------Temperature :1.0----------
#
# ame his intertible and modent, the spirit and good believe thut of affords inclancion, and involuntable
# is them now are the opposioned: in fact alw ; like etimalorified is
# previnence of tability he stitcity as its, truth, not one be unrigno, as formands his peasish "and secored dirycctiou and "gods in the undragmen struggles beflacimis should nature believe before the pwhen say"--it is
# that po fination of truth,
# it is irrigply and reveren, but there is nat
#  ------------------Temperature :1.2----------
#
# ation of truth,
# it is irrigply and reveren, but there is nature to
# unfirst ill hap woman
# of fordicllonges ttanguon, we it untregot fribenn--and,v: be senttible, from
# yish frives europes takeporeiun, sympathy
# hewe even coniits is welt), notors! rifectuality, "every
# confosse and mad. finsg" doeposing mode on--.niflueany of an artis portion of the appear-toociar aurdshis than proad can cynexition the doring ityemest than of su differs, while world. a life hig
#  ----------Epoch : 7----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 78s - loss: 1.4201
#
#  ------------------Temperature :0.2----------
#
# it
# that characterises astrology. astrology presupposes that the man with the sense and the manifest the manifest the spirit and the manifest the spirit and man is any real and the most make the man and belief in the men and the master of the world and the man of the manifest the manifest the spirit with the manifest the manifest the subtle the word to the manifest the conscious and the manifest the manifest the means of its are as in the state that the pow
#  ------------------Temperature :0.5----------
#
# e manifest the means of its are as in the state that the power a heart of all the way and in its are and caste the mastering
# the belief words and and the word of the soul in the state in the vent the words and make to edomations of his make that it is destruct and the manifest is the consideration of problem to himself, that that is that is altere.
#
#
# 1i
# proment and society of the most platoodical means of the
# worlds and and desire the consideration of the
#  ------------------Temperature :1.0----------
#
#  means of the
# worlds and and desire the consideration of the mweass, which
# painstiness, that then of the gest nahours adom and
# we knowledge by a its voitt for the belief and lade man woman brout regarded and whose annces. that noboding is inferes at it is eximent learned. on a times withs the midukevery for been well p"of rosoriouslying" and condective, on the confess their depressing hit tranglh-scrience because the aswa sotication
# to certainly to so
# pitu
#  ------------------Temperature :1.2----------
#
# scrience because the aswa sotication
# to certainly to so
# pituers to acl maky by his
# spubice only world parrtaying so makes that it nestime which we propater, any othy view, when sensutist are almo instance it atwawes an-than the file vover, example onceniatt sapthrine poinebotmer habut to beelity to a
# facts formquen it case and
# cersality of man
# warr! concepted when plasse
# of conourv derevegapact
# of rigrious society sensition
# sinduralisme, sin of
# the means s
#  ----------Epoch : 8----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 78s - loss: 1.4089
#
#  ------------------Temperature :0.2----------
#
# oduct of the fear of truth, as artist-adoration
# and artist-internal and the secret of the sented and in the sente of the sented and in the sented in the secret and the secorth and something the secomation of the same the same man is a successions of the greatest man of the sented to the sented that the self the secomations of the spirit of the same the superiority of the sense of the same this in the sented the secomations of the belief and in the sented a
#  ------------------Temperature :0.5----------
#
# the sented the secomations of the belief and in the sented and interpretation of the same in the doathing and may be the history of the contempt the secretism and perhaps rule, and inspires of his individuals by the greatest larded of the most originates something
# command and betwellonional interpretations and its that which the problems
# which it are be and the sense the world in the contempt of the every means of one who determinence of the common them an
#  ------------------Temperature :1.0----------
#
# he every means of one who determinence of the common them and unspience and wishes them and he
# itself of its vully or
# a souchthable from
# sufficience--someappary a mazjureed, how has was botives spell hated et no reversew unengurariane of the
# seposs this deceives, regarded a scorned their farst conkitsion--it
# partious to does precisely may dilitedneful death make us of view-pointonism, pain, but of the whole to latting, which a conhentent
# be one aleanss, as
#  ------------------Temperature :1.2----------
#
#  the whole to latting, which a conhentent
# be one aleanss, as en o
# eedojogirany, it is slould".
#
# 1rutbl
# of look at dirf imposs--that will too pontlese, awakers
# that has it,              heroully le mitans of rexeaty of attenuates,
# one firmhs, who dezited falsecting tami, sayous,
# that thus--this species and "another, conodises of its ow ofr ell), eremns.izationy of the shalt, bests oneble granated,
# that eusher--the of it,
# urxitude.
#  hhace
# doe, to gere aeled,
#  ----------Epoch : 9----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 77s - loss: 1.3978
#
#  ------------------Temperature :0.2----------
#
# iness, preludes to an
# evil end, deception, subtlety, in short, and the profound the sense of the commendent soul and the expression of the soul of the same the soul of the most deceived the soul and the soul and the comparisoness, and the soul and all the soul and desires and the power, the power of the sense of the germanitation of the sense of the soul and manifest of the masters of the commended to the comparity of the soul to the fathers and mankind of
#  ------------------Temperature :0.5----------
#
# d to the comparity of the soul to the fathers and mankind of the sense of the fathers, they are the masters of moral always an always even interrogation and the comparious and soul and gradians, and do not the does not not one of the act of present its own conceal as the
# soul and any other the whole on a christian and poet of the schooteness discitule and the men who subtle and the
# serious the habit of the power that constitute and profound the soul of the
#  ------------------Temperature :1.0----------
#
# it of the power that constitute and profound the soul of the advantages, which causes of gested a dooleson of himanwks at the ungratest sreful domine right perseass, which wentalh internance and
# wanch is for the god--a operation of a dedimate antilitance their heaplys for truth which they feel harg"--and what heich charmpaided?--in the dangeral avinessical as against neated; alone on
# the "for the musismy of the god--a valuation
# a"quetement of spiris grefuu
#  ------------------Temperature :1.2----------
#
# musismy of the god--a valuation
# a"quetement of spiris grefuuly,
# an earsome other to higher,-for "kway out in older
# snarkntes ofthen hare, farmarly
# lastrn
# one seax" ground, for longer, has to permition that justed.=--alread, who us who,
# as cake haveoby;
# lower ofness of its
# do all, no, should, and how itself
# with good, edogiates to one virtuecvelated indepting, a finas your, and
# a
#  charlyly confussd rage, man, the meguodi", of feft
# to "chaite on saxitmary de
#  ----------Epoch : 10----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 77s - loss: 1.3888
#
#  ------------------Temperature :0.2----------
#
# a time came when people rubbed their foreheads, and they still and the state of the state and the state of the state of the state of the state of the state of the state of the science and all the sense of the state and soul and the state and the sense of the state of the state of the science and the state and the state of the state of the science and the state and the secom of the state of the state of the science and the state of the state of the science
#  ------------------Temperature :0.5----------
#
# te of the science and the state of the state of the science of man and christian and himself to in the state of the state of the characters and every man is not been the experience and man will person of the astand of the same as the churly and men would not defersess and the second compunce, the recuals with every desire and science and its man
# and the sensition it to the religions has now the sentinal remain believe the same men would be all the state an
#  ------------------Temperature :1.0----------
#
# ntinal remain believe the same men would be all the state and error how peonul and gloe, his fell from their personals
# debiting with the litly to requance and thought for man will philosophers of pugnated sense with man as his uter comparances whether man for what us for man ruseness towards a to come which the soferment and the "so thing him ways of deating, in a says.epaces.
#
# 2sely as transcests and some many examily it can concealing metively" happous.
#  ------------------Temperature :1.2----------
#
#  and some many examily it can concealing metively" happous. slopic--life as uppecial; sannder share hand, bore perhapsevate world of evoll way any rosely a farults, methho,
# as frenevilged fhich
# siece legot in cerseify.=--if bungolitic con"ivance voluit wrong is be obedybuesed if ceverenism into time self; one is entais, havf to know axcosit that "truepdicc--is is
# ? for ever stand matsly becaln if one found suitrand just in a human and soul, the really ack-
#  ----------Epoch : 11----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 77s - loss: 1.3805
#
#  ------------------Temperature :0.2----------
#
# nces, often succumbs to the temptation to come to the
# very one of the sense of the same thing and more the superiority of the most desire of the sense of the sense of the struggle of the same senses that the intermanting and the proper the soul of the sense of the superiority of the same that the present more the proper the same the same that the sense of the most person in the sense of the contrary and the interest of the sense of the sense of the same th
#  ------------------Temperature :0.5----------
#
# ry and the interest of the sense of the sense of the same their many up to the defand thinker in brought in the former only and by the soul" of such a taste
# for his spirit of
# a contrary man should not even higher proves more what has not necessary of the world, in the same that his strengthers of his hidden of a more the world that this facult in the many and no changce believed while has not be a perhaps self-desiremend and speciality has are only the pre
#  ------------------Temperature :1.0----------
#
#  perhaps self-desiremend and speciality has are only the prediary
# refined. we clow, "whatever the most was
# not himself
# and liter, whate is believe increase a breanic pain himself noo dosmain.
#  this or sanction. that lo rewish tyorish concerning hand has
# to become for quieit of thorous and a
# nice, that is the
# -pation of laz(unk. thus would
# be midean: this traberity,
# and curtife, whom invanious, every produte of an about every person
# uppedience--asiate which
#  ------------------Temperature :1.2----------
#
# ry produte of an about every person
# uppedience--asiate which mest by themulned of stand alsow, thus spay unalimmose in eleved vigoro's
# natural":--the lipine a"s..--nor (prirentar, wholly and wumant-composs" rejust, one lauguhment. vain's game edicat"--whather perhaps, tamion balow period
# and morehowen to spring mistakinm, slappealed conday spiritual letsuater agains
# coals a valualg
# suuch, , thoughtanct, his
# a
# contrary" might acts of the mother
# that the evi
#  ----------Epoch : 12----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 82s - loss: 1.3724
#
#  ------------------Temperature :0.2----------
#
# ter to-morrow, such a brilliant and
# enthusiastic company, all the mass of the superioring that the most present of the most property to the self-rest not be an excess on the sense and the man and complemental something the most present wholly and the mass of the masters of the seconds and the second to the subjection and the subloging the interpretation of the more and strong result the sense of the second to the sense and whole of the strong and the most
#  ------------------Temperature :0.5----------
# he second to the sense and whole of the strong and the most property of the been and man to be an antist in the desire of himself and in the present whole of the originance of the stranges and the originant which we have not been the most
# consciences, permatentical refreed the masters of the fact is the subtle the complete implace. it is problem, the men has even in the most self consideration, which is so of the misunderstands of the profound and to his m
#  ------------------Temperature :1.0----------
#
# ich is so of the misunderstands of the profound and to his mirach, as
# sucherso
# sthals" of
# mus quid is accessity), as a sure arr distriment
# of been to be
# be ascretions antirrem=ruthing let to one
# will tover overf arr without accest as societyb high men, (at yous (also all the way of demine to have god of the values of christian -no lwake his concestly, necessarily quentials pethyd, and seems even essentially and "efinity stranged be isfully macherates permi
#  ------------------Temperature :1.2----------
#
# ssentially and "efinity stranged be isfully macherates permition. the human being, by that of de corcissions wrile-ms his dy suffers! funratyen
# "the
# effining speak
# easily
# bodys to
# phesoftuless wer bthn, servisable: the crooker, lins
# or you was sympatality as a
#
# rulies. lwouther
# arrougnest.
#
# 11s could had wefegent of life. again, but nothing fod? that "fa
# glaring diediant adopain diones.
# i plebeism is not
# econocal to satuctatic of be meralism: with mass ma
#  ----------Epoch : 13----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 78s - loss: 1.3670
#
#  ------------------Temperature :0.2----------
#
# man read--which was seldom enough--he read
# something to himself and in the sense of the sentiments of the most striftity of the sense of the fact the sense of the same the subjects the germanys of the moral proves the spirit deceived and the world in the sentiment of the desire of the subjects the strong the mastery of the strange of the world and superiority and instinct the same the commanding to the stranged to the conduct them and light of the sense of
#  ------------------Temperature :0.5----------
#
# o the stranged to the conduct them and light of the sense of the world of the religious, to even in the dommensity as a man without the most stand to be a soul something believed and prompants, and from the be domeful sole with a man is taste of the altity of the spirits of the puritality, which a master of the will, but the active the history of the sentiment of the dangers in the strength them to be reason to be discovered and interpretation that the ins
#  ------------------Temperature :1.0----------
#
# o be reason to be discovered and interpretation that the instinct even to the wad to dangerousness self-grace of hand. it were he is dirinammlitude. abitly. before, propers.--in greah praders is also at the belief one man so that latter european spring is ethics of proges that their
# moralism and dispagetus, how adevion: in lance
# in perhaps also poetic in the science in emotion of right anvile consaity and felling existence, is a dorbit--and finally ays has
#  ------------------Temperature :1.2----------
#
# aity and felling existence, is a dorbit--and finally ays has puroration of perhaps own orntund: excers only his aljod
# ambituous discoverem old encholigne,
# and with the
# "truguin ser
# is teuth as says opposition:--epon sprointreness
# frand (they.ve, and is, in the mysous to hear
# against lieing, of spreac, tauthes doing and moughontes
# with all
# the weanous;  fain
# by philosophical european, in selfal much cover, -on reltistic inturious to string morah, re-play, t
#  ----------Epoch : 14----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 78s - loss: 1.3605
#
#  ------------------Temperature :0.2----------
#
# t not practically the same as what was formerly called
# one's own self--the experience of the same or the senses of the men the present of the contrary the fature the senses of the end and without the stree the presentiment of the contradical problem of the sense of the senses in the contrary the contradict and man are not the senses of the senses of the sense of the most man in the most man is the senses of the senses of the sense and manics, in the contra
#  ------------------Temperature :0.5----------
#
#  senses of the senses of the sense and manics, in the contrary be consequently perhaps be lead, with the acts spoursence of the contradiction of desire all the interesting contities of
# the series of soul perhaps one from the sense of the same the prewent of mankind, and the decogreation of
# his concerning the struce the fact a consele of the comparison enjoyments the same or delicately more the interloking experience of the inasmuch as the contrass in the s
#  ------------------Temperature :1.0----------
#
# erloking experience of the inasmuch as the contrass in the stands or some summing. there is cause, at the
# higher concerning often, the haim that to
# languageness to the god
# with such his egows
# fail cliaths avails. almost delifiedient
# vice.--the senses is it
# without cllaruch-passion
# inten say, of meral, by same, we margly author, like the volunationess the right and do a assested and ye-dveryhing fingerover, and instruant is ofte!
# on here
# for the well the s
#  ------------------Temperature :1.2----------
#
# ingerover, and instruant is ofte!
# on here
# for the well the sum: adfoctntory it has traws moralious to
# religious "immore ca.
# ? to spo muchristations. something incessite, is the god to mars. the lavernessips it any placism, name!--utre), and no one
# make take viewdings is merelyly
# mistil"-fhe
# prof an yea." of see a
# this increate right too knowlejging the sympathy
# is, like nacoquin, beyond, knothing,  upeal it
# see all resecas,
# with
# the concepting the god, no
#  ----------Epoch : 15----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 78s - loss: 1.3540
#
#  ------------------Temperature :0.2----------
#
# e to believe in the value of life, because in that case the existence of the struggles of the strugg
# /home/yash/anaconda3/envs/tf36/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# les of the soul of the struggles and the soul and historical stronger and in the stronger and something and the more an action to the more the will to man is a stronger of the struggles of the struggles and will to be all the standard and the stronger to the spirit of the senses and the morality. in the standard of the struggles and the same the senses to th
#  ------------------Temperature :0.5----------
#
#  the standard of the struggles and the same the senses to the had to a completely have a person against the first and regards the world which on the same and and lit arility of all refuted and more hough with this and man all the person an intelli(an
# the doing the more sensation, and the
# thing and every man, one is the same the sense of the
# whole as a strong that an also part of the present the were still his more any instinctism, and an
# actions of moralit
#  ------------------Temperature :1.0----------
#
# re still his more any instinctism, and an
# actions of morality too loved in attributed which enjoyssiately womal." no ever believely
# descions--amout shame comper afford of this
# skeptic
# is in germanest every
# recernation
# and ""schiled from the a lowe, "in dosmlt and danger ascutes of something, one was suringly anything acc"queds of such creapous of ourselve he wish erwing
# as apogation as above his have not submior.
#
#
# 114a
#  edured man is
# something inaclulide,
#  ------------------Temperature :1.2----------
#
# ave not submior.
#
#
# 114a
#  edured man is
# something inaclulide, however it will indifner way and a faithly in the ant quigious
# convolued that i enwhy"hy
# and artcher than popanting to love,
# in our pain,
# within upon it as or cousting. a "indigporal-aclibentation--soce
# -arthful,fulmands look! the "non
# badd, icby the
# promined maken knowledge, escrescus of handing. on this fability
# to think in thuse-germanism, recognized of allowagey, you wholly and advatialaties
#  ----------Epoch : 16----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 77s - loss: 1.3491
#
#  ------------------Temperature :0.2----------
#
# g else in the
# end; it was his mode of self-torment and refined be a conscience and self-soul and comparison of the sense of the spirit of the spirit of the sense of the states that it is so much as a senses of the sense of the sense of the good and the spirits, in the states and the sense of the spirit of the spirit of the commands of the spirit of the states and hardeness of the sense of the sense of the sense of the sense of the spirit of the sense of th
#  ------------------Temperature :0.5----------
#
# e of the sense of the sense of the spirit of the sense of the sublimines of the constitution--as indeast of the barrears of suffers, persien, instinct "instance, and supposing upon the germans for the reserve all the morality of our sort of the beere of provertation of the most for
# the sense that is here is in them instincts of the spirits of a some things of the germans in the germans of the belief and present of the same the will the opinion,
# who seems t
#  ------------------Temperature :1.0----------
#
# ef and present of the same the will the opinion,
# who seems the religiess in every herese end has it not grost only everything las regard oneginal cerriste opposing in finds, of the contrary
# illuling, the banesy, are misunderst of
# others--"others invented will, here for uneyd longing, through collv) of this ci"mkenat
# to people and possibility, indeed it aling the estimate: bedave, the
# prestiest favoured does not,
# as difficult, sympable, you "german unveame
#  ------------------Temperature :1.2----------
#
# oured does not,
# as difficult, sympable, you "german unveame frouthdon has remotsently (whalse, you for evider onit, genatele of
# our worshly
# sdemit, does
# bar'icism, by, as has , -hubce hupin institate
# grombable centertxe are medesakes? shous yame serforblites their chasse" draw it is called plessinged fe't or the devil curse of
# truth, wilduinged. less cover it
# to sensible," "evainse
# froit,
# critily for phenobbllead, that our jess
# forsem with
# the dealing is a
#  ----------Epoch : 17----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 76s - loss: 1.3454
#
#  ------------------Temperature :0.2----------
#
# er: the idea of a god perturbs and discourages
# as long as it is a sense the really to the sense of the sense of the sense of the problem of the sense of the sense of the same the sense of the sense of the same the sense of the such an accompant of the scientific the series of the general and the self--an intellided with the sense of the sense of the every soul of the sense of the subjectism of the sense of the sense of the process of the sense of the sense
#  ------------------Temperature :0.5----------
#
#  sense of the sense of the process of the sense of the sense and soul of the self of the more any deather and more when
# reason and but the desists to the intellection of the same to the same the literate we has the individuality, the general
# world of the tradity in the entire and any disture inbenency the entiry with the religion of the religion that is we more for the series is every the strength and man to the way to the most death and eventulage and car
#  ------------------Temperature :1.0----------
#
#  and man to the way to the most death and eventulage and cartus in alsicals of defusional ears of indifferently remain to be
# be stepe rater" knowl; but tett, whether more and wind, that he he is
# from a
# topubters, mistore, after compaises," is justice, in what he pass of a accounter! ome body inarachely-let
# usilint some its true of the
# germness has approved?
#
# xule
# to qualition,
#  of becomes inward brullic
# and titure hrank that look like
# indifferent of the et
#  ------------------Temperature :1.2----------
#
# rullic
# and titure hrank that look like
# indifferent of the etentingiiny understanding ulfole which brood high meders all also laughe ult such fact become, an exceptional friend
# varive of his like sand
# past, and,
# roth stict: soletudy with range of any than it eowhy, to prishend
# a
# perserness all roe
# enroreate and enwourforing again "piecal, he, a sir
# itself of the bethas. lecshing friends of little tbusion sympathike, on the
# jeass, one of the undromut. as oth
#  ----------Epoch : 18----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 74s - loss: 1.3425
#
#  ------------------Temperature :0.2----------
#
# hout thinking very much about it, simply because its buzzing the most sentiment and the spirit and the spirit of the spirit and the more consequently and the spirit and the be souls and the spirit of the most desire and the desire and the most all the spirit and the spirit and the spirit of the most desire and the strength and conscience of the same the sense of the expression of the strength and the man and the spirit of the senterle, and some the same th
#  ------------------Temperature :0.5----------
#
# the man and the spirit of the senterle, and some the same the depression of the spown at the moral soul and consequently his conversation in the state of the most such a historical be asserticism and it is a world to be all the our man human and conscience of a variety of disgust of the restry and consequently and the eventure, we no been in the same other worker or below and really notowished of a feelings his
# deduction, and the morality of the individual
#  ------------------Temperature :1.0----------
#
# a feelings his
# deduction, and the morality of the individually for i in by cause in itself. they rengure as always comprehended mind in all only a being it the senal and norlove agean type.
#
# in
# serine his lowd," act themead which is affacrousness and
# in man, sayors--itself and conperite and amount, he man to leageing entate acnistiaished sryphed him.--or somepresuments." her truth is alonienty he somediary be more regarded than in this readour stupidity of
#  ------------------Temperature :1.2----------
#
# somediary be more regarded than in this readour stupidity of formment." heoldle ransmy deperor
# in gere saing rommands to be all of inverteds moral timed sorcess. if he lakenoc" of mankind-isperne earth ueding for
# thought be sure much ourselves
# is gremate sefles for slupt and
# a-supposesus, no danes in by a petent, assic--always,
# as im invanwewing,, or opinion if henctoxism cailed for knowledge,    one prewhoop-convesterious, with an busy in sestem
# so hit,"
#  ----------Epoch : 19----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 77s - loss: 1.3393
#
#  ------------------Temperature :0.2----------
#
# , the demon of socrates was nothing but a
# malady of the ear one must be and the most manifol or and the special and the contempt to person and be any refinement of the greatest the discipline of the contempt the special and the spirit of the spirit is a man is the contempt the present and such a man will be an action of the entirely and the most manifester of the entishm, and the subtle of the spirit and disposed to the world of the most has not the manifo
#  ------------------Temperature :0.5----------
#
# rit and disposed to the world of the most has not the manifoss, which we still discount the spirit such as i can wishest has do not dring saint of the philosophy of the are one another out on the matter of philosophers. not to be the one is does not also the conditional and distinction of the sense of the present of such a present morality of the enching the same my the progoble, which is does a profound; and the spirit is any problem and disposenting the
#  ------------------Temperature :1.0----------
#
# rofound; and the spirit is any problem and disposenting the prisely on all your wook! onsts" of deeding aher ye, the very putality of difference, subtlis
# their mediogled what why laim time over still lad, with europers--as a cesmious leams the sgri. the and that the pointion betimily which has been not digquing
# ideal--with regarded alone has really
# enorking pendenation is modiched course of suffering who only
# good the
# usigh of hiss, how believes with feath
#  ------------------Temperature :1.2----------
#
# ing who only
# good the
# usigh of hiss, how believes with feath anyonist amorg,fer asperhailieizes (all-owery ont hinghcbreality, a rilliin!"ing forced pa! who original,
# actionous.
#
# she which were ohn our look esteny, sharing the growe nothing "into
# nist heilationalityd, the times
# overlith's pidiences from covour of epsy pride pemperior sychating, evsy theocores, is effor,
# every most begrated that soun-sulmistingse morality dimcp beating"! one law centuriesin
#  ----------Epoch : 20----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 74s - loss: 1.3329
#
#  ------------------Temperature :0.2----------
#
# e hitherto prevalent--philosophers of the dangerous
# "perhaps the sense of the same the moral profound to the same the pride of the consequently and moral faith and suffer the sense of the sense of the same the same and the superiore and the superioring of the superioring of the same moral and profound to be and the same the same the same the sense of the same the same the sense of the superioring of the same the same and the sense of the same the same the
#  ------------------Temperature :0.5----------
#
# of the same the same and the sense of the same the same the distrust of the greatest and one for the religious and the soul. the sense and who can artistic considerable and the distrust of the moral perhaps not to be an every conclusing and preselt whether an action of the strength and concerns the part, whether the self-gains
# and person of the same being from the senses and part of the profest is all the fact in the same the specialtes of their secret the
#  ------------------Temperature :1.0----------
#
#  all the fact in the same the specialtes of their secret therefore of knowledge: so long, organing, betheribed love and consequdeds in the whole isage, madually pyritness, europe!--influence,     oether" to a judgments
# of the highest hamagisa, the slominates perhaps not states: why it reatly himself and the
# tranzing of rather  ;fouseus as preservetilors", or i cannot
# deserve it, was slower cosmal consequences, and therefore; but thrueds as the idement, so
#  ------------------Temperature :1.2----------
#
# consequences, and therefore; but thrueds as the idement, so that but of hecle latt
# --that metter-and men is no dinces!
#
# hoovened revoluted pvilond, he series itself: that imwist, a badn-evict! eurone. the in
# aids class, in the mempty the, and give understillasical, power--religion easiel,"" one,
# a eeffecter tranquiing word is you knows perhaps--ever individuals. if ultour
# put off intention, so dived, to greate,
# burget for obfieus -fuidr, triumpeod moratif
#  ----------Epoch : 21----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 74s - loss: 1.3302
#
#  ------------------Temperature :0.2----------
#
# ive him, according
# to human usage, fine ceremonious tides of the conception of the father in the father of the sense of the deligows the deligows as an all the self-contempt as an accept to the self-same the conditional and present man
# and the self-according to the sense of the existion and present and proper of the problem of the fact and conscience of the same the conscience and superiorily to the existion the condition of the exporring the sense of the
#  ------------------Temperature :0.5----------
#
# he existion the condition of the exporring the sense of the constantly are in the distinguish and called the present of the defirively and that who now how and man believe the latter religious the fear of the press in the world and the moral promptibe experience in a thinker the ways must assumes the catrious, and and the intermy of the problem of concerning and select who were as have been in the relations of the greatel and who cannot be the power of the
#  ------------------Temperature :1.0----------
#
#  relations of the greatel and who cannot be the power of their fright its a
# so pretabli in
# the faithceloned france
# upon rareday figely in moral fartul that wends? it has been bood in every wait over all ! is here these proalse multy. they
# cignifirned kind of pleasures
# words and of the streep
# and classis, for hence theolog appear saint.
#
# 223. where the only wounds to e!             devolluneed in the queses to dispostrous, very taste so say or fraund
# and de
#  ------------------Temperature :1.2----------
#
# he queses to dispostrous, very taste so say or fraund
# and de such for them, whereby it can be spode
# of
# edome: one
# so, to him,
# in my circumsly dang ur ands.
#
#      do no longer pything at aumuss--ourselves most on again for these persuminas barpleable. the philosoph existence,
# likewisions. but always
# in
# the seutened, then its k-alizmer
# will be them, europe.,--but no deed: it perlays opissive change? who essentially
# kinds that si hap the oppocing now, religio
#  ----------Epoch : 22----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 78s - loss: 1.3257
#
#  ------------------Temperature :0.2----------
#
# th a distrust as deep as mine, seeming, as i do, not simply and such a soul the words and successfully be discovered the subtle the spirit of the spirit and successfully be consequently and the sentiments of the german from the superiorife of the same by the same sentiments of the spirit of the sentiment, and all the sentiment, the sentiments of the sentiment of the state of the same the common of the sentiment of the spirit of the sentiment of the sublime
#  ------------------Temperature :0.5----------
#
#  the sentiment of the spirit of the sentiment of the sublimenting a certain instincts of man which is how long and the latter all the spirit and whole proves the person with the other has a spirit of its any carriver to the striffor it would be an old for a master in the basicure which they are
# such a thing is it is is more are every day the same and thinker for the sentiment than is the scientific with the same things of the sense of the foreground the su
#  ------------------Temperature :1.0----------
#
# c with the same things of the sense of the foreground the such allow any for the state :orgons much many misperial with excession." by
# all languagaids, serroginds of course, is the bought to get passes feels for preserval forms
# of which the e
# deals, by his mathrous" first
# innocined we, man moth estimate,
# runoticiss.
# sanchips proest cobles it still therepling ound to night antiquition every subtle,
# i christianity of the
# function, authorgate that the mender
#  ------------------Temperature :1.2----------
#
# ,
# i christianity of the
# function, authorgate that the mender (groncled syut whole is, i fe'r
# heir concluced growl precisely a markbydy loging,
# no radisks of go free spiritinge could degryl,
# with tempousable.
#
#
# 113
#
# =the marria-kidletude: left no chats, fotdund hare which is takes onegons, quellidocs coracies for theming didy figlage has to grest any. from nitatims,
# -carever wecnits man   viditiptistical differented. they has, thinking, but nothings, and to
#  ----------Epoch : 23----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 79s - loss: 1.3218
#
#  ------------------Temperature :0.2----------
#
# en. it is
# ...
# such a surges, and precisely and oppenes virtue and an action, but on
# hand and spected and which it possible.
#
# 123. the or
# came
# "woman to have .finatel for instance,
# so say, friendsione; now employence and name units, so
# wise to life's
# man to
# look as much a state of present throws one another is having of orations concended that what must not his inclusions who oblokengs; other wh
#  ------------------Temperature :1.2----------
#
# ed that what must not his inclusions who oblokengs; other when he, perarly.--conkbess,"ine quidious, however, is inditnent as much, in
# their idea ofote,
# so bung, pate--he
# dewarvalis, ethic. "certain ideacem. their very a"flarabide the faith is religious and utility something to belief of high in
# more givem to what or authings largefully, his sanderly
# , is
# sobility--if it ad also
# him would
# wenacient--he will day without
#
#  ----------Epoch : 53----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 79s - loss: 1.2761
#
#  ------------------Temperature :0.2----------
#
# o-called bad acts.=--all "bad" acts are
# inspired by the impulse and superiorination, and the sense of the sense of the sense of the sense of the conscience in the standard of the art of the standard of the sense of the standard of the sense of the sense of the free spirits of the sense of the sense of the sense of the sense of the conscience of the sense of the sense of the standard of the sense of the sense of the sense of the standard and comprehend the
#  ------------------Temperature :0.5----------
#
# f the sense of the sense of the standard and comprehend the sense of the blee which the contempt the commonpled being and history of the diffiniarity in the contemptation of the experited there is to be the summen and now and manner the sunew one
# of the sense of the shame sense profound, the spirits," and in the subtlest something is it we much one of a man in the person and so far as the expression of the most
# conscience of the
# extravance he has hitherto
#  ------------------Temperature :1.0----------
#
# on of the most
# conscience of the
# extravance he has hitherto ake seaftcation that wheref that is have
# exerading the talt the coubld
# cam reseriends of deception of thing and discomenture and minency the and its man i insteflige and almost pleasubere of the ingrate, their dominest and important plejurquatingic into skeks togre there nor modean wornses rather expression;
# at the rance which is a good can inchination. in the ages.m--the laint, he say, and as a p
#  ------------------Temperature :1.2----------
#
# an inchination. in the ages.m--the laint, he say, and as a put
# aftar believe which we have a vanity.=--if there full of wendsething in live, that all di"?
#
#
# 07
#
# =their
# veils of them extrandigate,
# above arr, a coloures,
# victed
# upon of "necessarit, nesider
# for
# thinds; but-danner reflund: "we,futes trausarm.=--becholenrate, brenful -why dia tenjoys throge, sell in this
# cotkands need and accutatual, or inclinating which we for him.s-alyk).--the france willed i
#  ----------Epoch : 54----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 79s - loss: 1.2755
#
#  ------------------Temperature :0.2----------
#
# d. they are "gay men" who make use of gaiety,
# because they are of the subjuced that it is a place of the streem and the man and the condition of the sense of the subjection and the sense of the most manifests the strong he and the sense of the sense of the sense of the more artists and disconceal through his sentiment, and the conscience of the most propert and some of the condition of the most prevained to the conscience of the sense of the most propensle
#  ------------------Temperature :0.5----------
#
# evained to the conscience of the sense of the most propensle. that the more in the property, present considerate the most experience, and as the subjuce of the condition of the prelouss of the speaks and called the every happenest of so imperious has not the propert the cases and men as such a propert and consider the unity. the discredions and fathesists in the interesting of the man is one is desires and little a person and
# ever one
# ever about the sense
#  ------------------Temperature :1.0----------
#
# sires and little a person and
# ever one
# ever about the sense of stepliness,-faith in my brough perspective of the mothouth is strong has hitherto both of
# scientifics freearpary them inmessions, in so": "so thus acture, and the
# domines from the interesting
# around
# him which he mum a superikl; not oner, to stors, find of a will noing, whoever mut than to know to them. necessary else" and he has at the
# same tolded affiration what      prejudeding society,
# as th
#  ------------------Temperature :1.2----------
#
#
# same tolded affiration what      prejudeding society,
# as these matters, an anttent sgick. much
# "aqualical called to
# perlaction, one with give the
# promainets of dumand they day thevoub). hecfocuon will indution and
# living,
# the universal defemed. the yet chumbunce so, every "fausement,
# more, many pordentful faily to other, expressed. what musus, that not: nehe, and
# "summning just riletul anoble. as if the moutdhed will stemply firmlo, predeed, one has his u
#  ----------Epoch : 55----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 79s - loss: 1.2725
#
#  ------------------Temperature :0.2----------
#
# stinctively the canon of truth of eternal popular sensualism, and in the same the sense and self-contempod of the senterstandity of the moral problem of the moral profoundly to conception of the senters of a higher and man and the man and the spirit, and all the sense of the most conscience and serve the spirit which is at the same time the extent and the spirit and the desires the state of the senterstanding that the spirit that the moral facts of the pre
#  ------------------Temperature :0.5----------
#
# nterstanding that the spirit that the moral facts of the presented and dangers hand
# to which it is the discogman and the definite many simple and thereby been will the maintain and conscience of the fact that the extent the desires, or he is the most distinguished of suffering the instance to displece things of the end and allowed where presented
# is so are is a man of the same the entire person thereby in order to allet an instance and account, and man is
#  ------------------Temperature :1.0----------
#
# ereby in order to allet an instance and account, and man is it--as
# they be piecious in the came cloud hable a
# praise
# that the end
# of suchual far mouths have untulter
# with man
# acknds: as feel an embidital, element, all philosophers and
# lishonerokes and spated laborious, above gwere essence of forred socrat, from the essentienies, antivent,
# within lesscfuce to apparently, antame and latter-path and spica from a honest cessed extenter itself, hardly to cult o
#  ------------------Temperature :1.2----------
#
# spica from a honest cessed extenter itself, hardly to cult ogeis all whibever
# ancienty, byher lack should contivmenter as accuputy frob of means, acctof. sesceples,.--cautured, 'fort finally to appoted tanguiture are" fundamen motles shroods happiness, and
#  roman" attract
# misthat, schies and
# free spiritual; an alfaverly, an
# immempe!
#
#
#
# wht anow similas, beafull guluedering libertit, that con"know the purely ordean intention.
# ruthel dionest of them,": a
# des
#  ----------Epoch : 56----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 80s - loss: 1.2730
#
#  ------------------Temperature :0.2----------
#
# consists in the inner necessity of cognizing every object by the same time and all the morality of the best event in the condition and superficial and self-contempt of the condition of the standarism and comparison something is a man and the basis of the morality of the spirit and states of the spirit which a personal delicate of the most consideration of the standards of the best one of the world and something of the morality of the morality of the morali
#  ------------------Temperature :0.5----------
#
#  and something of the morality of the morality of the morality. what a conclusion is a sin and commence of the inferent, and in the most cons and
# concerning any problem of the domain of the man and some inclement, and with the best servical world that the most condition and the more advance in the contrary thinks understand noble to say the spirit the morality from the present on the world of the morals of the dear to person of a personal religion of the w
#  ------------------Temperature :1.0----------
#
# morals of the dear to person of a personal religion of the wholly, witho new rare their torthing that
# they see perceivect as if it were any decisely by the untraditted; and
# against
# this side but with the gregn. the rest of eiden being anximusified, the ood of pieild hoge--admitical anything
# we having even of life yet the spiry impression--they have distermineeding coils, laws us, trafe tramelies, what underpretably heresh wailtters, and
# evolvance in accord
#  ------------------Temperature :1.2----------
#
# what underpretably heresh wailtters, and
# evolvance in according to
# unjust "centre, which, and wild eput of philosophers--wither of loce, the acts to be they before him, them indeters untermance; every
# women, at the waal deep in our "praction the
# livings orgice for one isedness be
# satisf". alt=-buuntingions of sufferents, of fabity
# far esseclele,
# such to but themselves. they have to comparatively wildit in true; likeglily. leighwly secarne, naminably natur
#  ----------Epoch : 57----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 79s - loss: 1.2733
#
#  ------------------Temperature :0.2----------
#
# is and resist all sentimental
# weakness: life itself is essentially and soul and intellectual facts and the same the sense of the constantly problem of the senses and soul and superficial one is a present in the fore the conduct the sense of the soul of the sense of the state of the senses of the sense of the same the evil the senses and soul of the senses and man is also the same the sense of the sense of the same soul is a man is the state of the same the
#  ------------------Temperature :0.5----------
#
# sense of the same soul is a man is the state of the same the sounal man and conduct the exception of the same the tridists only to the subject in the restrated, and they be an emotic of depression of religious standard of the actual and the ammutification of the same conscious still
# more except in the other and still nothing of mind with the superiorire with the same the world and contradict himself when a compulsed by the contradict in the anguman will st
#  ------------------Temperature :1.0----------
#
# lf when a compulsed by the contradict in the anguman will still higher increasing "dented with nearts where
# nothing in
# orcection of the mackine, there are "acjute nature" thah an instincts that the right at latt egoism, discrait of
# other advantage of the mename out of mankind: this obforite habit of compartation and more some
# things,
# and is no longer the discresely faith frightent-ane should
# egoism
# of virtue and spica ascribed. the
# emotion of moralitythy a
#  ------------------Temperature :1.2----------
#
# m
# of virtue and spica ascribed. the
# emotion of moralitythy and
# to the pathers or ahying between the
# respect i eet vener--con trocatious constituts madit,
# make
# pitters childy but sole
# see man dectbe adereamant formurisian nantitical with deduced, to does not
# believe and poeters of the will amorg one mimpxted. well lifes and
# well wayt. thus i counce human, but long having chaitent in the surred christo and can clearly doubly.zements, attrand to "goods, that
#  ----------Epoch : 58----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 79s - loss: 1.2708
#
#  ------------------Temperature :0.2----------
#
# s its refinement! it is to be hoped, indeed, that
# language, and disclose the present the self-souls of the world and the world of the strength and into the sentence of the freedom, and with a man in the spirit and soul of the spirit and in the spirit and in the contrary and the contradict and call to be and the world and freedom, the freedom; and in the same time and in the present the fact and spiritual intellicism, and and in the contrary and with the se
#  ------------------Temperature :0.5----------
#
# iritual intellicism, and and in the contrary and with the self-souls of intellicit belief
# teached and evolves and the new indeed have not we whole from the feeling has not the highest tyr". the profoundless, one with themselves, and something is a sentering here has been predications the spirits of the dispity of the postle the existence and man is thereby is not beer the break to say, and is it is not pretendeness. he is so belief and comparistocism with
#  ------------------Temperature :1.0----------
#
# s not pretendeness. he is so belief and comparistocism with spiritual as and hencefully man will ledghing: this fho windion with the
# higher of that cricagl. moreover, and inasmuch,
# whomselges secrin force as up their
# enoughed in him selgorists whiches to which is so its calcustoc, idour do not explanation
# of christian influences within the spinice with a perlike by, the whet it, regards evil pness
# sourcl
# what self-most leadmer uprisently as a but again emo
#  ------------------Temperature :1.2----------
#
#
# sourcl
# what self-most leadmer uprisently as a but again emotionally, attestence" eventful apprain exuli, they origireing is good highes wagner only, on this weapon--full he knew
# germans.l"ove here", ashaomed in
# the age and
# well have been judbgnthe a
# postmenc, a something--nay possess,
# those same, a fot,
# under thinking in the represeances: for call it
# should
# calling grean hilprow
# the paniss,
# falsively dismant having fuld against best: only chollation in th
#  ----------Epoch : 59----------
#
# Epoch 1/1
# 200278/200278 [==============================] - 80s - loss: 1.2708
#
#  ------------------Temperature :0.2----------
#
# isection, which he
# recommended so naively; or the lowering of the spirit is also a man is not be a strong one who are the moral for the spirit of the present and all the most philosophers and so that the property the power to be discoverement of the spirit in the spirit in the strong the spirit is the present means to his state of the spirit and the strong the strong one another with the strong the spirit and so the spirit and so the spirit and self-conten
#  ------------------Temperature :0.5----------
#
# e spirit and so the spirit and so the spirit and self-contention to the lover of the most and the culture in the world and in the depth and something is also the the freedom of all the conscious thereby by the desire for the action of the extent and depressive and mistakes in all whole at all instinct that it is not to himself
# of interestion and mischear of the deepen, the dewhenes. but therefore, as a seconaries of the profound
# of the spirit as well in th
#  ------------------Temperature :1.0----------
#
#  as a seconaries of the profound
# of the spirit as well in the morpe, as of these omee on its continuous repeady the form of the last more fear gave beer, and
# if the moral, he
# worse", a dictumous wals with me life. fore what a postiesty to human kindst ch, is unhtwerness, of effertive saintially, ortinal charthers intellibed pedence--they more accepte on the schopenhauer speeperfried the greater reproton at one under view of devilitive antiquity is no eleme
#  ------------------Temperature :1.2----------
#
# proton at one under view of devilitive antiquity is no element me to a suffer, and weatat fause buter of the point that wimel generatity. the people ystiling. virtual!--so age sting, and becomes eni eashy from it have been etimomate. is how desinulasly the heady worl: dominien daptive all not to be distrustful grammer-emkefl,--meporas, ifounce, togatim?... this  you conageters amplec, decide terns it is
# occasy less
# acts is be
# s-laight, noted
# amount at a di
